# %%
import numpy as np

X = np.array([[1, 1, 1, -1], [-1, -1, 1, 1]])   #This is the input pattern matrix X.
Y = np.array([[1, -1], [-1,1]])                 #This is the output pattern matrix Y 
W = np.dot(Y.T, X)

def bam(x):
    return np.sign(np.dot(W, x))

x_test = np.array([1, -1, -1, -1])
y_test= bam(x_test)

print("Input x",x_test)
print("Output y",y_test)
# Out:
# Input x [ 1 -1 -1 -1]
# Output y [ 1 -1]
